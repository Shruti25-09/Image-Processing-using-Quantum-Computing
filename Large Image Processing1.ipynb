# %%
# Importing standard Qiskit libraries and configuring account
from qiskit import *
from qiskit import IBMQ
from qiskit.compiler import transpile, assemble
from qiskit.tools.jupyter import *
from qiskit.visualization import *

#Import Numpy and Matplotlib
import numpy as np
from numpy import asarray
import matplotlib.pyplot as plt
from matplotlib import style
style.use('bmh')

#Import Pillow for greyscale
import PIL
from PIL import Image

import os
import math

# Detection algorithm works with an NxN matrix
N=32
#N is a power of 2

# %%
#Plot Image
def plot_image(img, title: str):
    plt.title(title)
    
    if img.shape[0] <= 32:
        plt.xticks(range(img.shape[0]))
        plt.yticks(range(img.shape[1]))
    
    plt.imshow(img, extent=[0, img.shape[0], img.shape[1], 0], cmap='viridis')
    plt.show()

# %%
#Normalize -- squared amplitudes must sum to 1
def amplitude_encode(img_data):
    img_data = img_data.astype(float)    
    # Calculate the RMS value
    rms = np.sqrt(np.sum(np.sum(img_data**2, axis=1)))
    
    # Create normalized image
    image_norm = []
    for arr in img_data:
        for ele in arr:
            image_norm.append(ele / rms)

    #assert np.sum(np.square(image_norm)) == 1, f"Sum of amplitudes-squared does not equal one. Sum is: {np.sum(np.square(image_norm))}"

    # Return the normalized image as a numpy array
    return np.array(image_norm)

# %%
def blockshaped(arr, nrows, ncols):
    # Return an array of shape (n, nrows, ncols) where
    # n * nrows * ncols = arr.size

    # If arr is a 2D array, the returned array should look like n subblocks with
    # each subblock preserving the "physical" layout of arr.
    # Coutesy of Stack Exchange

    #formerly h,w,k. Greyscale only has h,w
    h, w = arr.shape
    assert h % nrows == 0, f"{h} rows is not evenly divisible by {nrows}"
    assert w % ncols == 0, f"{w} cols is not evenly divisible by {ncols}"
    return (arr.reshape(h//nrows, nrows, -1, ncols)
               .swapaxes(1,2)
               .reshape(-1, nrows, ncols))

# %%
#Open image and convert to greyscale using Pillow library
img_raw = Image.open(os.path.join("bigcroppedskyline3.png"))
img_grey_raw = img_raw.convert('L')
#img_grey_raw.save('test_grey.jpg')
img_grey = np.asarray(img_grey_raw)

#Image is n blocks of M x K pixels
n, m = img_grey.shape
print('Raw Image info:', img_grey.shape)
print('Raw Image datatype:', img_grey.dtype)

cropSize = 32

#Image must be a square that can be divided into cropSize x cropSize Blocks
if n != m:
    raise Exception("Image must be square")
if n % cropSize != 0:
    raise Exception(f"Image cannot be converted to an {N} by {N} Blocks")

#Print image
def plot_image_large(img, title: str):
    plt.title(title)
    plt.imshow(img, extent=[0, img.shape[0], img.shape[1], 0], cmap='viridis')
    plt.show()
    
plot_image_large(img_grey, 'Original Image')
# Out:
# Raw Image info: (1024, 1024)
# Raw Image datatype: uint8

# %%
#Creates Blocks of cropSize x cropSize pixels
img = blockshaped(img_grey, cropSize, cropSize)
print(img.shape)

#Size should be (cropSize^2) * (# of blocks)
print(img.size)
# Out:
# (1024, 32, 32)
# 1048576

# %%
#normalize amplitudes of each block
img_normH = []
img_normV = []
i = 0

for block in img:
    img_normH.append([])
    img_normV.append([])
    img_normH[i] = amplitude_encode(block)
    img_normV[i] = amplitude_encode(block.T)

    i = i + 1

# %%
# qubit amount
# data_qb should be math.ceil(math.log2(N))
data_qb = math.ceil(math.log2(N**2))
anc_qb = 1
total_qb = data_qb + anc_qb

# Initialize the amplitude permutation unitary
D2n_1 = np.roll(np.identity(2**total_qb), 1, axis=1)

# %%
#circuit computation
svH = []
svV = []

for j in range(0, len(img)):
    # horizontal scan circuit
    print(f"Progress: {j + 1} of {len(img)}")
    qc_h = QuantumCircuit(total_qb)
    qc_h.initialize(img_normH[j], range(1, total_qb))
    qc_h.h(0)
    qc_h.unitary(D2n_1, range(total_qb))
    qc_h.h(0)

    # vertical scan circuit
    qc_v = QuantumCircuit(total_qb)
    qc_v.initialize(img_normV[j], range(1, total_qb))
    qc_v.h(0)
    qc_v.unitary(D2n_1, range(total_qb))
    qc_v.h(0)

    # Combine both circuits
    circ_list = [qc_h, qc_v]

    #---#

    # run simulator
    svH.append([])
    svV.append([])

    back = Aer.get_backend('statevector_simulator')
    results = execute(circ_list, backend=back).result()
    svH[j] = results.get_statevector(qc_h)
    svV[j] = results.get_statevector(qc_v)

    j = j+1
# Out:
# Progress: 1 of 1024
# Progress: 2 of 1024
# Progress: 3 of 1024
# Progress: 4 of 1024
# Progress: 5 of 1024
# Progress: 6 of 1024
# Progress: 7 of 1024
# Progress: 8 of 1024
# Progress: 9 of 1024
# Progress: 10 of 1024
# Progress: 11 of 1024
# Progress: 12 of 1024
# Progress: 13 of 1024
# Progress: 14 of 1024
# Progress: 15 of 1024
# Progress: 16 of 1024
# Progress: 17 of 1024
# Progress: 18 of 1024
# Progress: 19 of 1024
# Progress: 20 of 1024
# Progress: 21 of 1024
# Progress: 22 of 1024
# Progress: 23 of 1024
# Progress: 24 of 1024
# Progress: 25 of 1024
# Progress: 26 of 1024
# Progress: 27 of 1024
# Progress: 28 of 1024
# Progress: 29 of 1024
# Progress: 30 of 1024
# Progress: 31 of 1024
# Progress: 32 of 1024
# Progress: 33 of 1024
# Progress: 34 of 1024
# Progress: 35 of 1024
# Progress: 36 of 1024
# Progress: 37 of 1024
# Progress: 38 of 1024
# Progress: 39 of 1024
# Progress: 40 of 1024
# Progress: 41 of 1024
# Progress: 42 of 1024
# Progress: 43 of 1024
# Progress: 44 of 1024
# Progress: 45 of 1024
# Progress: 46 of 1024
# Progress: 47 of 1024
# Progress: 48 of 1024
# Progress: 49 of 1024
# Progress: 50 of 1024
# Progress: 51 of 1024
# Progress: 52 of 1024
# Progress: 53 of 1024
# Progress: 54 of 1024
# Progress: 55 of 1024
# Progress: 56 of 1024
# Progress: 57 of 1024
# Progress: 58 of 1024
# Progress: 59 of 1024
# Progress: 60 of 1024
# Progress: 61 of 1024
# Progress: 62 of 1024
# Progress: 63 of 1024
# Progress: 64 of 1024
# Progress: 65 of 1024
# Progress: 66 of 1024
# Progress: 67 of 1024
# Progress: 68 of 1024
# Progress: 69 of 1024
# Progress: 70 of 1024
# Progress: 71 of 1024
# Progress: 72 of 1024
# Progress: 73 of 1024
# Progress: 74 of 1024
# Progress: 75 of 1024
# Progress: 76 of 1024
# Progress: 77 of 1024
# Progress: 78 of 1024
# Progress: 79 of 1024
# Progress: 80 of 1024
# Progress: 81 of 1024
# Progress: 82 of 1024
# Progress: 83 of 1024
# Progress: 84 of 1024
# Progress: 85 of 1024
# Progress: 86 of 1024
# Progress: 87 of 1024
# Progress: 88 of 1024
# Progress: 89 of 1024
# Progress: 950 of 1024
# Progress: 951 of 1024
# Progress: 952 of 1024
# Progress: 953 of 1024
# Progress: 954 of 1024
# Progress: 955 of 1024
# Progress: 956 of 1024
# Progress: 957 of 1024
# Progress: 958 of 1024
# Progress: 959 of 1024
# Progress: 960 of 1024
# Progress: 961 of 1024
# Progress: 962 of 1024
# Progress: 963 of 1024
# Progress: 964 of 1024
# Progress: 965 of 1024
# Progress: 966 of 1024
# Progress: 967 of 1024
# Progress: 968 of 1024
# Progress: 969 of 1024
# Progress: 970 of 1024
# Progress: 971 of 1024
# Progress: 972 of 1024
# Progress: 973 of 1024
# Progress: 974 of 1024
# Progress: 975 of 1024
# Progress: 976 of 1024
# Progress: 977 of 1024
# Progress: 978 of 1024
# Progress: 979 of 1024
# Progress: 980 of 1024
# Progress: 981 of 1024
# Progress: 982 of 1024
# Progress: 983 of 1024
# Progress: 984 of 1024
# Progress: 985 of 1024
# Progress: 986 of 1024
# Progress: 987 of 1024
# Progress: 988 of 1024
# Progress: 989 of 1024
# Progress: 990 of 1024
# Progress: 991 of 1024
# Progress: 992 of 1024
# Progress: 993 of 1024
# Progress: 994 of 1024
# Progress: 995 of 1024
# Progress: 996 of 1024
# Progress: 997 of 1024
# Progress: 998 of 1024
# Progress: 999 of 1024
# Progress: 1000 of 1024
# Progress: 1001 of 1024
# Progress: 1002 of 1024
# Progress: 1003 of 1024
# Progress: 1004 of 1024
# Progress: 1005 of 1024
# Progress: 1006 of 1024
# Progress: 1007 of 1024
# Progress: 1008 of 1024
# Progress: 1009 of 1024
# Progress: 1010 of 1024
# Progress: 1011 of 1024
# Progress: 1012 of 1024
# Progress: 1013 of 1024
# Progress: 1014 of 1024
# Progress: 1015 of 1024
# Progress: 1016 of 1024
# Progress: 1017 of 1024
# Progress: 1018 of 1024
# Progress: 1019 of 1024
# Progress: 1020 of 1024
# Progress: 1021 of 1024
# Progress: 1022 of 1024
# Progress: 1023 of 1024
# Progress: 1024 of 1024

# %%
# Classical postprocessing and plotting

# lambda function for binary value thresholding
threshold = lambda amp: (amp > 1e-15 or amp < -1e-15)

scanTotalH = []
scanTotalV = []
k = 0

for listH, listV in zip(svH, svV):

    # select odd states (lists) from raw statevectors and 
    # reshape column vector to NxN
   
    scanTotalV.append([])
    scanTotalH.append([])
    scanTotalV[k] =     edge_scan_v = np.abs(np.array([1 if threshold(listV[2*i+1].real) else 0 for i in range(2**data_qb)])).reshape(cropSize, cropSize).T
    scanTotalH[k] =     edge_scan_h = np.abs(np.array([1 if threshold(listH[2*i+1].real) else 0 for i in range(2**data_qb)])).reshape(cropSize, cropSize)

    k = k+1

#plot_image_large(scanTotalH[7], "edge detection, my beloved")

# %%
img_full = []

for j in range(0, int(n/cropSize)):
    for i in range(0, int(n/cropSize)):
        temp = scanTotalH[i + (j*int(n/cropSize))] | scanTotalV[i + (j*int(n/cropSize))]
        if i == 0:
            img_row = temp
        else:
            img_row = np.concatenate( (img_row, temp), axis = 1)

    if j == 0:
        img_full = img_row
    else:
        img_full = np.concatenate( (img_full, img_row), axis = 0)

print(img_full.shape)
# Out:
# (1024, 1024)

# %%
plot_image_large(img_full, "edge detection")
